# %%
import numpy as np
import matplotlib.pyplot as plt

from utils.dataset import train_test_load
from model.train import training_loop

# %%
test_split = 0.2

train, test = train_test_load("data/ml-latest-small/ratings.csv", test_split=test_split)

# %%
train_loss, train_rmse, test_loss, test_rmse, user_bias, movie_bias, user_embeddings, movie_embeddings = training_loop(
    train.user_movies, train.movie_users, test.user_movies,
    embedding_dim = 2, r_lambda = 0.05, r_gamma = 0.05, r_tau = 0.05, n_iter = 20,
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train_loss, train_rmse, test_loss, test_rmse, user_bias, movie_bias, user_embeddings, movie_embeddings = training_loop(
#       2     train.user_movies, train.movie_users, test.user_movies,
#       3     embedding_dim = 2, r_lambda = 0.05, r_gamma = 0.05, r_tau = 0.05, n_iter = 20,
#       4 )
#
# File ~/Projects/recommender-system/model/train.py:180, in training_loop(train_user_movies, train_movie_users, val_user_movies, embedding_dim, r_lambda, r_gamma, r_tau, n_iter)
#     175 movie_embeddings = np.random.normal(
#     176     0, np.sqrt(embedding_dim), (n_user, embedding_dim)
#     177 )
#     179 for iter in range(n_iter):
# --> 180     optimize_users(
#     181         train_user_movies,
#     182         embedding_dim,
#     183         r_lambda,
#     184         r_gamma,
#     185         r_tau,
#     186         user_bias,
#     187         movie_bias,
#     188         user_embeddings,
#     189         movie_embeddings,
#     190     )
#     191     optimize_movie(
#     192         train_movie_users,
#     193         embedding_dim,
#    (...)    200         movie_embeddings,
#     201     )
#     203     train_loss[iter] = compute_loss(
#     204         r_lambda,
#     205         r_gamma,
#    (...)    211         movie_embeddings,
#     212     )
#
# File ~/Projects/recommender-system/model/train.py:82, in optimize_users(train_user_movies, embedding_dim, r_lambda, r_gamma, r_tau, user_bias, movie_bias, user_embeddings, movie_embeddings)
#      76 for user_idx in nb.prange(len(train_user_movies)):
#      77     movies, ratings = train_user_movies[user_idx]
#      79     n_bu = np.sum(
#      80         ratings
#      81         - (
# ---> 82             movie_embeddings[movies] @ user_embeddings[user_idx]
#      83             + movie_bias[movies]
#      84         )
#      85     )
#      86     m_vv = movie_embeddings[movies].T @ movie_embeddings[movies]
#      87     r_vs = movie_embeddings[movies].T @ (
#      88         ratings - movie_bias[movies] - user_bias[user_idx]
#      89     )
#
# IndexError: index 610 is out of bounds for axis 0 with size 610

# %%
fig, axs = plt.subplots(2, 1, figsize=(8, 6))

axs[0].plot(train_loss, label="Train loss")
axs[0].plot(test_loss, color="forestgreen", label="Test loss")
axs[0].set_xlabel("Iteration")
axs[0].set_ylabel("Loss")
axs[0].set_title("Loss at each iteration")
axs[0].legend()

axs[1].plot(train_rmse, label="Train RMSE")
axs[1].plot(test_rmse, color="forestgreen", label="Train RMSE")
axs[1].set_xlabel("Iteration")
axs[1].set_ylabel("RMSE")
axs[1].set_title("RMSE at each iteration")
axs[1].legend()

plt.tight_layout()
# plt.savefig("32m_10K_training.svg", format="svg")
plt.show()
